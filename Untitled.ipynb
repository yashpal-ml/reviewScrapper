# %%
from flask import Flask, render_template, request,jsonify
from flask_cors import CORS,cross_origin
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url = "https://www.flipkart.com/search?q="+"iphone"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone'

# %%
uClient = uReq(flipkart_url)

# %%
type(uClient)
# Out:
# http.client.HTTPResponse

# %%
flipkartpage = uClient.read()

# %%
type(flipkartpage)
# Out:
# bytes

# %%
flipkartpage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.4f01cc.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
uClient.close()

# %%
flipkart_html = bs(flipkartpage, 'html.parser')

# %%
type(flipkart_html)
# Out:
# bs4.BeautifulSoup

# %%
flipkart_html
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
big_boxes = flipkart_html.findAll("div", {"class":"_1AtVbE col-12-12"})

# %%
len(big_boxes)
# Out:
# 31

# %%
for i in big_boxes:
    print(i)
# Out:
# <div class="_1AtVbE col-12-12" style="padding:0px 0px 10px 0px"><a class="UYS4aW _3E_YdP" href="/tyy/4io/~cs-23pjn3d2my/pr?sid=tyy%2C4io&amp;collection-tab-name=iphone+13&amp;ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkFwcGxlIGlQaG9uZSAxMyJdLCJ2YWx1ZVR5cGUiOiJNVUxUSV9WQUxVRUQifX19fX0%3D&amp;otracker=sp_browse_announcement_search.flipkart.com"><div class="_3ywSr_" style="padding-top:53.57%"><div class="_1bEAQy _312yBx" style="padding-top:53.57%"><img alt="iPhone 13" class="_2OHU_q _2WCh1J"/><img alt="iPhone 13" class="kJjFO0 _3DIhEh _9JTfqZ" src="https://rukminim2.flixcart.com/flap/100/54/image/f99cad9816ac2a4e.jpg?q=50"/></div></div><div class="_1sPNy4"><div class="_2LR_KO">Apple iPhone 13</div><div class="tMzY0d">From ₹74,900 | 5000 instant discount on HDFC CC/DC EMI</div></div></a></div>
# ...

# %%
box =big_boxes[5]

# %%
box_href = box.div.div.div.a['href']

# %%
box_href
# Out:
# '/apple-iphone-13-midnight-128-gb/p/itmca361aab1c5b0?pid=MOBG6VF5Q82T3XRS&lid=LSTMOBG6VF5Q82T3XRSOXJLM9&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=d67c42a9-5c75-47d2-9bd8-cfd15d275526.MOBG6VF5Q82T3XRS.SEARCH&ppt=None&ppn=None&ssid=ddh41di0fk0000001649483676133&qH=0b3f45b266a97d70'

# %%
productlink = 'https://www.flipkart.com'+box_href

# %%
productlink
# Out:
# 'https://www.flipkart.com/apple-iphone-13-midnight-128-gb/p/itmca361aab1c5b0?pid=MOBG6VF5Q82T3XRS&lid=LSTMOBG6VF5Q82T3XRSOXJLM9&marketplace=FLIPKART&q=iphone&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=d67c42a9-5c75-47d2-9bd8-cfd15d275526.MOBG6VF5Q82T3XRS.SEARCH&ppt=None&ppn=None&ssid=ddh41di0fk0000001649483676133&qH=0b3f45b266a97d70'

# %%
prodres = requests.get(productlink)

# %%
prodres
# Out:
# <Response [200]>

# %%
prodres.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.4f01cc.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/ap
# ...

# %%
prod_html = bs(prodres.text, 'html.parser')

# %%
prod_html
# Out:
# <!DOCTYPE doctype html>
# ...

# %%
prod_html('div',{'class':'_16PBlm'})
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Perfect product!</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Awesome camera <br/>Amazing battery life <br/>Super xdr display is 💕👌🏻<br/>Playing games and day to day task are smooth <br/>Face ID is superb<br/>iOS 15 is really awesome 🤩 thanks to Apple</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202201/blobio-imr-202201_0ec49f00497c42a98b01f30d187ac9d9.jpeg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr-202201/blobio-imr-202201_f96a9d4c45174bd38f0c9e89b97f03c2.jpeg?q=90), url(data:image/svg+xml;base64,...);w
# ...

# %%
commentboxes = prod_html.find_all('div', {'class': "_16PBlm"})

# %%
reviews=[]

# %%
for commentbox in commentboxes:
    name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
    rating = commentbox.div.div.div.div.text
    commentHead = commentbox.div.div.div.p.text
    
    comtag = commentbox.div.div.find_all('div', {'class': ''})
    #custComment.encode(encoding='utf-8')
    custComment = comtag[0].div.text
    
    mydict = {"Product": 'iphone', "Name": name, "Rating": rating, "CommentHead": commentHead, "Comment": custComment}
    reviews.append(mydict)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-7e166f8f961a> in <module>()
#       1 for commentbox in commentboxes:
# ----> 2     name = commentbox.div.div.find_all('p', {'class': '_2sc7ZR _2V5EHH'})[0].text
#       3     rating = commentbox.div.div.div.div.text
#       4     commentHead = commentbox.div.div.div.p.text
#       5
#
# AttributeError: 'NoneType' object has no attribute 'div'
